# %% [markdown]
# # **UTS**
#
# * Lakukan analisa klasifikasi terhadap data abstrak prodi teknik informatika pta.trunojoyo.ac.id dengan menggunakan model klasifikasi naïve bayes dan KNN denga preprossing reduksi dimensi PCA (principal component analysis)

# %% [markdown]
# ## Prepocessing data

# %% [markdown]
# ## Membaca Data

# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv("/content/drive/MyDrive/prosaindata/tugas/cleaneddata.csv")
df
# Out:
#      Unnamed: 0           NIM                     Nama  \
# 0             0   40411100468       A.Ubaidillah S.Kom
# 1             1   40411100476      M. Basith Ardianto,
# 2             2   70411100070          Heri Supriyanto
# 3             3   80411100115     Septian Rahman Hakim
# 4             4   70411100007      Adi Chandra Laksono
# ..          ...           ...                      ...
# 787         793  160411100032    Rachmad Agung Pambudi
# 788         794  160411100182         Nadila Hidayanti
# 789         795  160411100077             Afni Sakinah
# 790         796  160411100084  Friska Fatmawatiningrum
# 791         797  160411100044              Dian Wibowo
#
#                                                  Judul  \
# 0    perancangan dan implementasi sistem database t...
# 1    aplikasi kontrol dan monitoring jaringan kompu...
# 2    sistem pendukung keputusan optimasi penjadwala...
# 3    sistem augmented reality animasi benda bergera...
# 4    gerak pekerja pada game real time strategy men...
# ..                                                 ...
# 787  penerapan algoritma long short term memory unt...
# 788  sistem pencarian teks al quran terjemahan berb...
# 789  klasifikasi kompleksitas visual citra sampah m...
# 790  identifikasi biner atribut pejalan kaki menggu...
# 791  deteksi objek manusia berbasis one stage detec...
#
#                                                Abstrak      Kelas  \
# 0    sistem informasi akademik siakad merupakan sis...        RPL
# 1    berjalannya koneksi jaringan komputer dengan l...        RPL
# 2    penjadwalan kuliah di perguruan tinggi merupak...  Komputasi
# 3    seiring perkembangan teknologi yang ada diduni...  Komputasi
# 4    gerak pekerja ada pada game yang memiliki genr...        RPL
# ..                                                 ...        ...
# 787  investasi saham selama ini memiliki resiko ker...        NLP
# 788  information retrieval ir merupakan pengambilan...  Komputasi
# 789  klasifikasi citra merupakan proses pengelompok...  Komputasi
# 790  identifikasi atribut pejalan kaki merupakan sa...        NLP
# 791  topik deteksi objek telah menarik perhatian ya...  Komputasi
#
#                                           judul_tokens  \
# 0    ancang implementasi sistem database distribusi...
# 1    aplikasi kontrol monitoring jaring komputer ba...
# 2    sistem dukung putus optimasi jadwal matakuliah...
# 3    sistem augmented reality animasi benda gerak f...
# 4    gerak kerja game real time strategy finite sta...
# ..                                                 ...
# 787  terap algoritma long short term memory prediks...
# 788  sistem cari teks al quran terjemah bahasa indo...
# 789  klasifikasi kompleksitas visual citra sampah k...
# 790  identifikasi biner atribut pejal kaki adaptive...
# 791  deteksi objek manusia bas one stage detector a...
#
#                                         abstrak_tokens
# 0    sistem informasi akademik siakad sistem inform...
# 1    jalan koneksi jaring komputer lancar ganggu ha...
# 2    jadwal kuliah guru kompleks masalah variabel t...
# 3    iring kembang teknologi dunia muncul teknologi...
# 4    gerak kerja game milik genre rts real time str...
# ..                                                 ...
# 787  investasi saham milik resiko rugi gera harga s...
# 788  information retrieval ir ambil informasi simpa...
# 789  klasifikasi citra proses kelompok piksel citra...
# 790  identifikasi atribut pejal kaki salah teliti k...
# 791  topik deteksi objek tarik perhati kembang tekn...
#
# [792 rows x 8 columns]

# %%
df.isna().sum()
# Out:
# Unnamed: 0        0
# NIM               0
# Nama              0
# Judul             0
# Abstrak           0
# Kelas             0
# judul_tokens      0
# abstrak_tokens    0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 792 entries, 0 to 791
# Data columns (total 8 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Unnamed: 0      792 non-null    int64
#  1   NIM             792 non-null    int64
#  2   Nama            792 non-null    object
#  3   Judul           792 non-null    object
#  4   Abstrak         792 non-null    object
#  5   Kelas           792 non-null    object
#  6   judul_tokens    792 non-null    object
#  7   abstrak_tokens  792 non-null    object
# dtypes: int64(2), object(6)
# memory usage: 49.6+ KB

# %%
df = df.dropna()
df.isnull().sum()
# Out:
# Unnamed: 0        0
# NIM               0
# Nama              0
# Judul             0
# Abstrak           0
# Kelas             0
# judul_tokens      0
# abstrak_tokens    0
# dtype: int64
