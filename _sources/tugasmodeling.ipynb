# %% [markdown]
# # **Modeling**

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
# !pip install numpy
# !pip install pandas
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %% [markdown]
# ## Tugas Crawling Komentar Youtube
#
# langkah yang dilakukan dalam mengaktivasi API Google
# *   Login ke Goggle Developer Console dengan akun Google
# Link :
# [Google Developer Console ](https://console.developers.google.com/)
# *   Buat **Project baru** dan lengkapi isi yang diminta
# *   Setelah masuk pada laman projek yang dibuat, kemudian klik **"ENABLE APIS AND SERVICES"** dan pilih **YouTube Data API v3**
# *   Kemudian klik **Try This API **
# *   Dari halaman dashboard, buat kredential agar API tersebut dapat digunakan.
# [**Buat Kredensial (Create Credential)**](https://console.cloud.google.com/apis/credentials?hl=id&project=youtube-crawling-386306)

# %% [markdown]
# **Import Library**

# %%
import pandas as pd
from googleapiclient.discovery import build

# %%
#fungsi mengambil data komentar di youtube
def video_comments(video_id):
	# empty list for storing reply
	replies = []

	# creating youtube resource object
	youtube = build('youtube', 'v3', developerKey=api_key)

	# retrieve youtube video results
	video_response = youtube.commentThreads().list(part='snippet,replies', videoId=video_id).execute()

	# iterate video response
	while video_response:
		
		# extracting required info
		# from each result object
		for item in video_response['items']:
			
			# Extracting comments ()
			published = item['snippet']['topLevelComment']['snippet']['publishedAt']
			user = item['snippet']['topLevelComment']['snippet']['authorDisplayName']

			# Extracting comments
			comment = item['snippet']['topLevelComment']['snippet']['textDisplay']
			likeCount = item['snippet']['topLevelComment']['snippet']['likeCount']

			replies.append([published, user, comment, likeCount])
			
			# counting number of reply of comment
			replycount = item['snippet']['totalReplyCount']

			# if reply is there
			if replycount>0:
				# iterate through all reply
				for reply in item['replies']['comments']:
					
					# Extract reply
					published = reply['snippet']['publishedAt']
					user = reply['snippet']['authorDisplayName']
					repl = reply['snippet']['textDisplay']
					likeCount = reply['snippet']['likeCount']
					
					# Store reply is list
					#replies.append(reply)
					replies.append([published, user, repl, likeCount])

			# print comment with list of reply
			#print(comment, replies, end = '\n\n')

			# empty reply list
			#replies = []

		# Again repeat
		if 'nextPageToken' in video_response:
			video_response = youtube.commentThreads().list(
					part = 'snippet,replies',
					pageToken = video_response['nextPageToken'], 
					videoId = video_id
				).execute()
		else:
			break
	#endwhile
	return replies

# %% [markdown]
# **Menjalankan proses crawling**

# %%
# isikan dengan api key Anda
api_key = 'AIzaSyBoRn9wIjryOsz7RDnl7Rcul4hnQKWfEaU'

# Enter video id
# contoh url video = https://www.youtube.com/watch?v=xiyAOKCAOyY
video_id = "xiyAOKCAOyY" #isikan dengan kode / ID video

# Call function
comments = video_comments(video_id)

comments
# Out:
# [['2023-05-09T13:38:47Z',
#   'Heru Bambang',
#   'Benar klo kali ini pilih Prabowo. Yg 1 ini ikhlas n lapang dada n berpandangan luas !',
#   0],
#  ['2023-05-08T01:40:08Z',
#   'Mawar Merah',
#   'Sak karepmu kono pak WOWO....☝️☝️<br>Aku bersama kelg besarku di JAKARTA &amp; di BEKASI akan tetap dukung &amp; pilih pak GANJAR PRANOWO....👍👍<br>Pak GANJAR akan siap....👍👍 Bekerja &amp; berjuang untuk kesejahteraan RAKYAT INDONESIA 🇮🇩🇮🇩bukan untuk kesejahteraan para BOHIR2 &amp; kelg CENDANA yg skrg sdh pd merepat &amp; mendekat ke PRABOWO....!! ☝️☝️☝️<br>MERDEKA....💪💪🇮🇩🇮🇩<br>Pak GANJAR sll dihati ❤❤ dan sll dinanti di 2024 👍👍',
#   1],
#  ['2023-05-07T13:01:16Z',
#   'Jam Gadang',
#   'Tak bisa di percaya lagi...bermuka dua...haus jabatan..dah luntur kepercayaan rakyat...rakyat terpecah. eh...Manunggaling ke jokowi...wo wo ampun deh.',
#   0],
#  ['2023-05-06T10:14:00Z',
#   'Fitri Fitri',
#   'Mantaaap pak prabowo  ,presiden ke 8,amiin.',
#   0],
#  ['2023-05-05T15:51:38Z',
# ...

# %% [markdown]
# **Hasil Crawling**

# %%
df = pd.DataFrame(comments, columns=['Tanggal', 'Nama', 'Komentar', 'likeCount'])
df
# Out:
#                  Tanggal                  Nama  \
# 0   2023-05-09T13:38:47Z          Heru Bambang
# 1   2023-05-08T01:40:08Z           Mawar Merah
# 2   2023-05-07T13:01:16Z            Jam Gadang
# 3   2023-05-06T10:14:00Z           Fitri Fitri
# 4   2023-05-05T15:51:38Z    Arjuna Putra pandu
# 5   2023-05-08T01:45:19Z           Mawar Merah
# 6   2023-05-03T19:07:45Z              Fahmyksa
# 7   2023-05-03T16:36:40Z            sapu jagad
# 8   2023-05-03T16:20:07Z             Afif Udin
# 9   2023-05-03T15:57:46Z                  TAMI
# 10  2023-05-03T15:41:48Z                Mir Za
# 11  2023-05-03T15:32:30Z          Ummie Dhalfa
# 12  2023-05-06T06:25:36Z      Sahwan Firansyah
# 13  2023-05-03T15:25:00Z         Yurnita bahar
# 14  2023-05-03T15:23:43Z       faisal abdillah
# 15  2023-05-03T14:46:36Z    Iqbal Raya Pratama
# 16  2023-05-03T14:43:48Z           I Am GoVlog
# 17  2023-05-08T01:47:43Z           Mawar Merah
# 18  2023-05-03T14:41:27Z           Samui Japan
# ...

# %% [markdown]
# **Hasil Crawling**

# %%
df.to_csv('komentar youtube.csv', index=False)

# %% [markdown]
# ## **Preprocessing**

# %% [markdown]
# Text Cleaning

# %%
#install library
# !pip install sastrawi
# !pip install swifter
# !pip install gensim
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 209.7/209.7 kB 8.9 MB/s eta 0:00:00
# ...
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 830.9/830.9 kB 17.9 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 64.4 MB/s eta 0:00:00
# ...
#   Created wheel for swifter: filename=swifter-1.3.4-py3-none-any.whl size=16299 sha256=fec7e33a822901531adfad14b58e32aecad3ce5c7426a19aeb89d5eb03e7f4b7
#   Stored in directory: /root/.cache/pip/wheels/6c/bd/3e/2d6afc9bc36c9975f8e4215a270bbac6580c4361ebd6bb2323
# Successfully built swifter
# ...
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
#import library
import pandas as pd
import numpy as np
from string import punctuation
import re
import nltk

# %%
#proses menghilangkan simbol dan emoji
def remove_text_special (text):
  text = text.replace('\\t',"").replace('\\n',"").replace('\\u',"").replace('\\',"")
  text = text.encode('ascii', 'replace').decode('ascii')
  return text.replace("http://"," ").replace("https://", " ")
df['Komentar'] = df['Komentar'].apply(remove_text_special)
print(df['Komentar'])
# Out:
# 0     Benar klo kali ini pilih Prabowo. Yg 1 ini ikh...
# 1     Sak karepmu kono pak WOWO....????<br>Aku bersa...
# 2     Tak bisa di percaya lagi...bermuka dua...haus ...
# 3           Mantaaap pak prabowo  ,presiden ke 8,amiin.
# 4                             Nggak tau malu si Wowo. .
# 5     Biarkan sj nt klo kalah lagi kan bisa dpt LEBE...
# 6                                         piring cantik
# 7     Kalau tidak jadi mantri kmaren saya salud tapi...
# 8                                           prabowo yes
# 9     PAK PRABOWO 4THN ini sdh di samping Pak jokowi...
# 10                    Udh mulai kejang2 lagi pak ya...?
# 11    2019 saya pilih pak Prabowo,2024 saya pilih pa...
# 12      2014 2019 2004 saya pilih dia kasian kalo kalah
# 13                     Wek Wek semangat pak ganjarrrrrr
# 14                         Jngn mau kalo jadi cawapress
# 15                            Ridwan Kamil yakin menang
# 16    Agak mudaan dikit lah.. kalo ketuaan ntar mala...
# ...

# %%
#menghilangkan tanda baca
def remove_tanda_baca(text):
  text = re.sub("(@[A-Za-z0-9]+)|([^0-9A-Za-z \t])|(\w+:\/\/\S+)"," ",text)
  return text

df['Komentar'] = df['Komentar'].apply(remove_tanda_baca)
df['Komentar'].head(20)
# Out:
# 0     Benar klo kali ini pilih Prabowo  Yg 1 ini ikh...
# 1     Sak karepmu kono pak WOWO         br Aku bersa...
# 2     Tak bisa di percaya lagi   bermuka dua   haus ...
# 3           Mantaaap pak prabowo   presiden ke 8 amiin
# 4                             Nggak tau malu si Wowo
# 5     Biarkan sj nt klo kalah lagi kan bisa dpt LEBE...
# 6                                         piring cantik
# 7     Kalau tidak jadi mantri kmaren saya salud tapi...
# 8                                           prabowo yes
# 9     PAK PRABOWO 4THN ini sdh di samping Pak jokowi...
# 10                    Udh mulai kejang2 lagi pak ya
# 11    2019 saya pilih pak Prabowo 2024 saya pilih pa...
# 12      2014 2019 2004 saya pilih dia kasian kalo kalah
# 13                     Wek Wek semangat pak ganjarrrrrr
# 14                         Jngn mau kalo jadi cawapress
# 15                            Ridwan Kamil yakin menang
# 16    Agak mudaan dikit lah   kalo ketuaan ntar mala...
# ...

# %%
#proses menghilangkan angka
def remove_numbers (text):
  return re.sub(r"\d+", "", text)
df['Komentar'] = df['Komentar'].apply(remove_numbers)
df['Komentar']
# Out:
# 0     Benar klo kali ini pilih Prabowo  Yg  ini ikhl...
# 1     Sak karepmu kono pak WOWO         br Aku bersa...
# 2     Tak bisa di percaya lagi   bermuka dua   haus ...
# 3            Mantaaap pak prabowo   presiden ke  amiin
# 4                             Nggak tau malu si Wowo
# 5     Biarkan sj nt klo kalah lagi kan bisa dpt LEBE...
# 6                                         piring cantik
# 7     Kalau tidak jadi mantri kmaren saya salud tapi...
# 8                                           prabowo yes
# 9     PAK PRABOWO THN ini sdh di samping Pak jokowi ...
# 10                     Udh mulai kejang lagi pak ya
# 11        saya pilih pak Prabowo  saya pilih pak Anies
# 12                     saya pilih dia kasian kalo kalah
# 13                     Wek Wek semangat pak ganjarrrrrr
# 14                         Jngn mau kalo jadi cawapress
# 15                            Ridwan Kamil yakin menang
# 16    Agak mudaan dikit lah   kalo ketuaan ntar mala...
# ...

# %%
#proses casefolding
def casefolding(Comment):
  Comment = Comment.lower()
  return Comment
df['Komentar'] = df['Komentar'].apply(casefolding)
df['Komentar']
# Out:
# 0     benar klo kali ini pilih prabowo  yg  ini ikhl...
# 1     sak karepmu kono pak wowo         br aku bersa...
# 2     tak bisa di percaya lagi   bermuka dua   haus ...
# 3            mantaaap pak prabowo   presiden ke  amiin
# 4                             nggak tau malu si wowo
# 5     biarkan sj nt klo kalah lagi kan bisa dpt lebe...
# 6                                         piring cantik
# 7     kalau tidak jadi mantri kmaren saya salud tapi...
# 8                                           prabowo yes
# 9     pak prabowo thn ini sdh di samping pak jokowi ...
# 10                     udh mulai kejang lagi pak ya
# 11        saya pilih pak prabowo  saya pilih pak anies
# 12                     saya pilih dia kasian kalo kalah
# 13                     wek wek semangat pak ganjarrrrrr
# 14                         jngn mau kalo jadi cawapress
# 15                            ridwan kamil yakin menang
# 16    agak mudaan dikit lah   kalo ketuaan ntar mala...
# ...

# %% [markdown]
# ## Word Normalization

# %% [markdown]
# **Normalisasi Kata Tidak Baku**

# %%
#proses tokenisasi
# from nltk.tokenize import TweetTokenizer
nltk.download('punkt')
# def word_tokenize(text):
#   tokenizer = TweetTokenizer(preserve_case=False, strip_handles=True, reduce_len=True)
#   return tokenizer.tokenize(text)

df['review_token'] = df['Komentar'].apply(lambda sentence: nltk.word_tokenize(sentence))
df['review_token']
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# 0     [benar, klo, kali, ini, pilih, prabowo, yg, in...
# 1     [sak, karepmu, kono, pak, wowo, br, aku, bersa...
# 2     [tak, bisa, di, percaya, lagi, bermuka, dua, h...
# 3         [mantaaap, pak, prabowo, presiden, ke, amiin]
# 4                          [nggak, tau, malu, si, wowo]
# 5     [biarkan, sj, nt, klo, kalah, lagi, kan, bisa,...
# 6                                      [piring, cantik]
# 7     [kalau, tidak, jadi, mantri, kmaren, saya, sal...
# 8                                        [prabowo, yes]
# 9     [pak, prabowo, thn, ini, sdh, di, samping, pak...
# 10                  [udh, mulai, kejang, lagi, pak, ya]
# 11    [saya, pilih, pak, prabowo, saya, pilih, pak, ...
# 12              [saya, pilih, dia, kasian, kalo, kalah]
# 13               [wek, wek, semangat, pak, ganjarrrrrr]
# 14                   [jngn, mau, kalo, jadi, cawapress]
# ...

# %%
df.to_csv('hasil normalisasi.csv', index=False)

# %%
#Normalisasi kata tidak baku
normalize = pd.read_csv("/content/hasil normalisasi.csv")

normalize_word_dict = {}

for row in normalize.iterrows():
  if row[0] not in normalize_word_dict:
    normalize_word_dict[row[0]] = row[1]

def normalized_term(comment):
  return [normalize_word_dict[term] if term in normalize_word_dict else term for term in comment]

df['comment_normalize'] = df['review_token'].apply(normalized_term)
df['comment_normalize'].head(20)
# Out:
# 0     [benar, klo, kali, ini, pilih, prabowo, yg, in...
# 1     [sak, karepmu, kono, pak, wowo, br, aku, bersa...
# 2     [tak, bisa, di, percaya, lagi, bermuka, dua, h...
# 3         [mantaaap, pak, prabowo, presiden, ke, amiin]
# 4                          [nggak, tau, malu, si, wowo]
# 5     [biarkan, sj, nt, klo, kalah, lagi, kan, bisa,...
# 6                                      [piring, cantik]
# 7     [kalau, tidak, jadi, mantri, kmaren, saya, sal...
# 8                                        [prabowo, yes]
# 9     [pak, prabowo, thn, ini, sdh, di, samping, pak...
# 10                  [udh, mulai, kejang, lagi, pak, ya]
# 11    [saya, pilih, pak, prabowo, saya, pilih, pak, ...
# 12              [saya, pilih, dia, kasian, kalo, kalah]
# 13               [wek, wek, semangat, pak, ganjarrrrrr]
# 14                   [jngn, mau, kalo, jadi, cawapress]
# 15                       [ridwan, kamil, yakin, menang]
# 16    [agak, mudaan, dikit, lah, kalo, ketuaan, ntar...
# ...

# %% [markdown]
# **Tokenizing** (ada diatas)

# %% [markdown]
# ## **Stopwords Removal**

# %%
#Stopword Removal
nltk.download('stopwords')
from nltk.corpus import stopwords
txt_stopwords = stopwords.words('indonesian')

def stopwords_removal(filtering) :
  filtering = [word for word in filtering if word not in txt_stopwords]
  return filtering

df['stopwords_removal'] = df['comment_normalize'].apply(stopwords_removal)
df['stopwords_removal'].head(20)
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# 0     [klo, kali, pilih, prabowo, yg, ikhlas, n, lap...
# 1     [sak, karepmu, kono, wowo, br, kelg, besarku, ...
# 2     [percaya, bermuka, haus, jabatan, dah, luntur,...
# 3                  [mantaaap, prabowo, presiden, amiin]
# 4                          [nggak, tau, malu, si, wowo]
# 5     [biarkan, sj, nt, klo, kalah, dpt, lebel, capr...
# 6                                      [piring, cantik]
# 7     [mantri, kmaren, salud, skarang, gak, la, suar...
# 8                                        [prabowo, yes]
# 9     [prabowo, thn, sdh, samping, jokowi, beliaulah...
# 10                                    [udh, kejang, ya]
# 11                       [pilih, prabowo, pilih, anies]
# 12                         [pilih, kasian, kalo, kalah]
# 13                    [wek, wek, semangat, ganjarrrrrr]
# 14                              [jngn, kalo, cawapress]
# ...

# %%
df.to_csv('hasil removal-1.csv', index=False)

# %%
#stopword removal 2
data_stopwords = pd.read_csv("/content/hasil removal-1.csv")
print(data_stopwords)

def stopwords_removal2(filter) :
  filter = [word for word in filter if word not in data_stopwords]
  return filter

df['stopwords_removal_final'] = df['stopwords_removal'].apply(stopwords_removal2)
df['stopwords_removal_final'].head(20)
# Out:
#                  Tanggal                  Nama  \
# 0   2023-05-09T13:38:47Z          Heru Bambang
# 1   2023-05-08T01:40:08Z           Mawar Merah
# 2   2023-05-07T13:01:16Z            Jam Gadang
# 3   2023-05-06T10:14:00Z           Fitri Fitri
# 4   2023-05-05T15:51:38Z    Arjuna Putra pandu
# 5   2023-05-08T01:45:19Z           Mawar Merah
# 6   2023-05-03T19:07:45Z              Fahmyksa
# 7   2023-05-03T16:36:40Z            sapu jagad
# 8   2023-05-03T16:20:07Z             Afif Udin
# 9   2023-05-03T15:57:46Z                  TAMI
# 10  2023-05-03T15:41:48Z                Mir Za
# 11  2023-05-03T15:32:30Z          Ummie Dhalfa
# 12  2023-05-06T06:25:36Z      Sahwan Firansyah
# 13  2023-05-03T15:25:00Z         Yurnita bahar
# 14  2023-05-03T15:23:43Z       faisal abdillah
# 15  2023-05-03T14:46:36Z    Iqbal Raya Pratama
# 16  2023-05-03T14:43:48Z           I Am GoVlog
# 17  2023-05-08T01:47:43Z           Mawar Merah
# 18  2023-05-03T14:41:27Z           Samui Japan
# ...

# %% [markdown]
# ## **Stemming**

# %%
#proses stem
from Sastrawi.Stemmer.StemmerFactory import StemmerFactory
import string
import swifter
factory = StemmerFactory()
stemmer = factory.create_stemmer()

def stemming (term):
  return stemmer.stem(term)

term_dict = {}
for document in df['stopwords_removal_final']:
  for term in document:
    if term not in term_dict:
      term_dict[term] = ''

# %%
print(len(term_dict))
print("-----------------------------")
# Out:
# 191
# -----------------------------

# %%
for term in term_dict:
  term_dict[term] = stemming(term)
  print(term,":",term_dict[term])

print(term_dict)
print("-----------------------------")
# Out:
# klo : klo
# kali : kali
# pilih : pilih
# prabowo : prabowo
# yg : yg
# ikhlas : ikhlas
# n : n
# lapang : lapang
# dada : dada
# berpandangan : pandang
# luas : luas
# sak : sak
# karepmu : karepmu
# kono : kono
# wowo : wowo
# br : br
# kelg : kelg
# besarku : besar
# jakarta : jakarta
# amp : amp
# bekasi : bekas
# dukung : dukung
# ganjar : ganjar
# pranowo : pranowo
# berjuang : juang
# kesejahteraan : sejahtera
# rakyat : rakyat
# indonesia : indonesia
# bohir : bohir
# cendana : cendana
# skrg : skrg
# sdh : sdh
# pd : pd
# merepat : merepat
# mendekat : dekat
# merdeka : merdeka
# sll : sll
# dihati : hati
# dinanti : nanti
# percaya : percaya
# bermuka : muka
# haus : haus
# jabatan : jabat
# dah : dah
# luntur : luntur
# kepercayaan : percaya
# terpecah : pecah
# eh : eh
# manunggaling : manunggaling
# jokowi : jokowi
# wo : wo
# ampun : ampun
# deh : deh
# mantaaap : mantaaap
# presiden : presiden
# amiin : amiin
# nggak : nggak
# tau : tau
# malu : malu
# si : si
# ...

# %%
def get_stemming(document):
  return [term_dict[term] for term in document]

# %%
df['stemming'] = df['stopwords_removal_final'].swifter.apply(get_stemming)
# Out:
# Pandas Apply:   0%|          | 0/34 [00:00<?, ?it/s]

# %%
print(df['stemming'])
df.head(20)
# Out:
# 0     [klo, kali, pilih, prabowo, yg, ikhlas, n, lap...
# 1     [sak, karepmu, kono, wowo, br, kelg, besar, ja...
# 2     [percaya, muka, haus, jabat, dah, luntur, perc...
# 3                  [mantaaap, prabowo, presiden, amiin]
# 4                          [nggak, tau, malu, si, wowo]
# 5     [biar, sj, nt, klo, kalah, dpt, lebel, capres,...
# 6                                      [piring, cantik]
# 7     [mantri, kmaren, salud, skarang, gak, la, suar...
# 8                                        [prabowo, yes]
# 9     [prabowo, thn, sdh, samping, jokowi, biau, yg,...
# 10                                    [udh, kejang, ya]
# 11                       [pilih, prabowo, pilih, anies]
# 12                           [pilih, kasi, kalo, kalah]
# 13                    [wek, wek, semangat, ganjarrrrrr]
# 14                              [jngn, kalo, cawapress]
# 15                              [ridwan, kamil, menang]
# 16    [muda, dikit, kalo, ketua, ntar, kek, om, bide...
# ...

# %% [markdown]
# ## **Pembobotan Kata**

# %%
def joinkata(data):
  kalimat = ""
  for i in data:
    kalimat += i
    kalimat += " "
  return kalimat

text = df['stemming'].swifter.apply(joinkata)
text
# Out:
# Pandas Apply:   0%|          | 0/34 [00:00<?, ?it/s]
# 0     klo kali pilih prabowo yg ikhlas n lapang dada...
# 1     sak karepmu kono wowo br kelg besar jakarta am...
# 2     percaya muka haus jabat dah luntur percaya rak...
# 3                      mantaaap prabowo presiden amiin
# 4                               nggak tau malu si wowo
# 5     biar sj nt klo kalah dpt lebel capres abadi th...
# 6                                        piring cantik
# 7     mantri kmaren salud skarang gak la suara kmai ...
# 8                                          prabowo yes
# 9     prabowo thn sdh samping jokowi biau yg erti ma...
# 10                                       udh kejang ya
# 11                           pilih prabowo pilih anies
# 12                               pilih kasi kalo kalah
# 13                        wek wek semangat ganjarrrrrr
# 14                                 jngn kalo cawapress
# 15                                 ridwan kamil menang
# ...

# %%
import os
import pandas as pd
from nltk.tokenize import RegexpTokenizer
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.decomposition import TruncatedSVD

# %%
# Vectorize document using TF-IDF
tfidf = TfidfVectorizer(lowercase=True,
                        stop_words='english',
                        ngram_range = (1,1))
                       
# Fit and Transform the documents
train_data = tfidf.fit_transform(text)

# %%
#bobot kata terhadap masing masing topik
print(train_data)
# Out:
#   (0, 88)	0.3596704258911336
#   (0, 124)	0.3596704258911336
#   (0, 27)	0.3596704258911336
#   (0, 83)	0.3596704258911336
#   (0, 48)	0.3596704258911336
#   (0, 181)	0.25736131201112256
#   (0, 134)	0.19281144800269298
#   (0, 129)	0.24300591145734948
#   (0, 61)	0.3219111760195521
#   (0, 73)	0.2951205618827041
#   (1, 107)	0.1215739785722698
#   (1, 46)	0.1215739785722698
#   (1, 156)	0.2431479571445396
#   (1, 100)	0.1215739785722698
#   (1, 31)	0.1215739785722698
#   (1, 101)	0.1215739785722698
#   (1, 125)	0.1215739785722698
#   (1, 147)	0.09975515995697702
#   (1, 155)	0.1215739785722698
#   (1, 26)	0.1215739785722698
#   (1, 20)	0.1215739785722698
#   (1, 49)	0.10881078787228682
#   (1, 139)	0.09273106924746291
#   (1, 148)	0.2431479571445396
#   (1, 59)	0.10881078787228682
#   :	:
#   (30, 97)	0.36417928256864474
#   (30, 67)	0.3972389466384376
#   (30, 61)	0.3972389466384376
#   (31, 82)	0.19735449860211865
#   (31, 34)	0.19735449860211865
#   (31, 45)	0.19735449860211865
# ...

# %%
df_tfidf = pd.DataFrame(
    train_data.toarray().T, columns=[f'D{i+1}' for i in range(len(text))], index=tfidf.get_feature_names_out()
)
df_tfidf
# Out:
#               D1        D2   D3        D4   D5        D6   D7        D8  \
# aamiin  0.000000  0.000000  0.0  0.000000  0.0  0.000000  0.0  0.000000
# abadi   0.000000  0.000000  0.0  0.000000  0.0  0.269513  0.0  0.000000
# aja     0.000000  0.000000  0.0  0.000000  0.0  0.000000  0.0  0.316228
# ambisi  0.000000  0.000000  0.0  0.000000  0.0  0.000000  0.0  0.000000
# amiin   0.000000  0.000000  0.0  0.551538  0.0  0.000000  0.0  0.000000
# ...          ...       ...  ...       ...  ...       ...  ...       ...
# yen     0.000000  0.000000  0.0  0.000000  0.0  0.000000  0.0  0.000000
# yes     0.000000  0.000000  0.0  0.000000  0.0  0.000000  0.0  0.000000
# yg      0.257361  0.086992  0.0  0.000000  0.0  0.000000  0.0  0.000000
# yo      0.000000  0.000000  0.0  0.000000  0.0  0.000000  0.0  0.000000
# yoo     0.000000  0.000000  0.0  0.000000  0.0  0.000000  0.0  0.000000
#
#               D9       D10  ...  D25  D26  D27       D28  D29       D30  D31  \
# ...

# %% [markdown]
# ## **Latent Semantic Indexing using Scikit-Learn**

# %%
#
# Define the number of topics or components
num_components=10

# Create SVD object
lsa = TruncatedSVD(n_components=num_components, n_iter=100, random_state=42)

# Fit SVD model on data
lsa.fit_transform(train_data)

# Get Singular values and Components 
Sigma = lsa.singular_values_ 
V_transpose = lsa.components_.T

# %%
# Print the topics with their terms
terms = tfidf.get_feature_names_out()

# bobot setiap topik terhadap  dokumen
for index, component in enumerate(lsa.components_):
    zipped = zip(terms, component)
    top_terms_key=sorted(zipped, key = lambda t: t[1], reverse=True)[:5]
    top_terms_list=list(dict(top_terms_key).keys())
    print("Topic "+str(index)+": ",top_terms_list)
# Out:
# Topic 0:  ['prabowo', 'yes', 'maju', 'menang', 'pilih']
# Topic 1:  ['br', 'kalah', 'capres', 'abadi', 'biar']
# Topic 2:  ['menang', 'pilih', 'kasi', 'kalo', 'merah']
# Topic 3:  ['menang', 'kamil', 'ridwan', 'yes', 'merah']
# Topic 4:  ['maju', 'menang', 'ethes', 'jan', 'lawan']
# Topic 5:  ['rakyat', 'beliau', 'amp', 'angel', 'ganjar']
# Topic 6:  ['kalo', 'cawapress', 'jngn', 'dikit', 'muda']
# Topic 7:  ['beliau', 'yg', 'ganti', 'ndukung', 'muda']
# Topic 8:  ['merah', 'plecidenan', 'pleciden', 'angel', 'yes']
# Topic 9:  ['ya', 'kejang', 'udh', 'merah', 'plecidenan']
